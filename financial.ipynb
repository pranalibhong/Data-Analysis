# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
data =pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\unified mentor\Financial Analytics data.csv")

# %%
data
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0        1   Reliance Inds.        583436.72           99810.00
# 1        2              TCS        563709.84           30904.00
# 2        3        HDFC Bank        482953.59           20581.27
# 3        4              ITC        320985.27            9772.02
# 4        5          H D F C        289497.37           16840.51
# ..     ...              ...              ...                ...
# 483    496  Lak. Vilas Bank          3029.57             790.17
# 484    497            NOCIL          3026.26             249.27
# 485    498    Orient Cement          3024.32             511.53
# 486    499  Natl.Fertilizer          3017.07            2840.75
# 487    500        L T Foods              NaN                NaN
#
# [488 rows x 4 columns]

# %%
data.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              488 non-null    int64
#  1   Name               488 non-null    object
#  2   Mar Cap - Crore    479 non-null    float64
#  3   Sales Qtr - Crore  459 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.4+ KB

# %%
data.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       479.000000         459.000000
# mean   251.508197     28043.857119        3807.769804
# std    145.884078     59464.615831        9989.455784
# min      1.000000      3017.070000           0.000000
# 25%    122.750000      4843.575000         534.910000
# 50%    252.500000      9885.050000        1137.170000
# 75%    378.250000     23549.900000        2730.195000
# max    500.000000    583436.720000      110666.930000

# %%
data.isna().sum()
# Out:
# S.No.                 0
# Name                  0
# Mar Cap - Crore       9
# Sales Qtr - Crore    29
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Visualize the distribution of market capitalization
plt.hist(data['Mar Cap - Crore'], bins=20, edgecolor='k')
plt.title('Distribution of Market Capitalization')
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Frequency')
plt.show()

# %%
# Line plot of market capitalization over entries
plt.plot(data['S.No.'], data['Mar Cap - Crore'])
plt.title('Market Capitalization Over Entries')
plt.xlabel('S.No.')
plt.ylabel('Market Capitalization (Crore)')
plt.show()

# %%
import seaborn as sns

# Scatter plot of market capitalization vs quarterly sales
sns.scatterplot(x='Mar Cap - Crore', y='Sales Qtr - Crore', data=data)
plt.title('Market Capitalization vs Quarterly Sales')
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Quarterly Sales (Crore)')
plt.show()

# %%
# Bar chart to compare quarterly sales of different entries
plt.figure(figsize=(10, 6))
plt.bar(data['S.No.'], data['Sales Qtr - Crore'])
plt.title('Quarterly Sales of Different Entries')
plt.xlabel('S.No.')
plt.ylabel('Quarterly Sales (Crore)')
plt.xticks(rotation=45)
plt.show()

# %%
# Pair plot to show relationships between market capitalization and quarterly sales
sns.pairplot(data[['Mar Cap - Crore', 'Sales Qtr - Crore']])
plt.suptitle('Pair Plot of Market Capitalization and Quarterly Sales')
plt.show()
